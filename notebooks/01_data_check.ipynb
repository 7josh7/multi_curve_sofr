# %% [markdown]
# # Data Check
#
# Inspect the bundled synthetic SOFR and OIS snapshot before bootstrapping.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve().parent
SOURCE_ROOT = PROJECT_ROOT / 'src'
if str(SOURCE_ROOT) not in sys.path:
    sys.path.append(str(SOURCE_ROOT))

from sofr_curve_engine.bootstrap import load_market_data

market = load_market_data(PROJECT_ROOT)
market.fixings.head(), market.ois_curve.head()

# %%
print(market.config)
print('1M futures:', len(market.futures_1m))
print('3M futures:', len(market.futures_3m))
print('Swap quotes:', len(market.swaps))
